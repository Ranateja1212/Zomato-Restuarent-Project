# %% [markdown]
# # Zomato Restuarent Project - EDA

# %% [markdown]
# ![zomato-infinity-dining-916x516-1.jpg](attachment:zomato-infinity-dining-916x516-1.jpg)

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Read csv file or load dataset file

# %%
df = pd.read_csv(r'D:\New folder\zomato.csv',encoding='latin-1')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# Conclusion : Total data set of Zomato

# %%
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
# Conclusion : first top 3 results in our data.

# %% [markdown]
# Shape of the data

# %%
df.shape
# Out:
# (9551, 21)

# %%
# Conclusion : There are total 9551 rows and 21 columns in our data set.

# %% [markdown]
# Information of the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# # Conclusion : 1.There are 3 data sets in the data.one is float second one is int and the last one is objective
# 2.There are 3 float values and 5 integer values and 13 categorical variables in this data.
# 3.Cuisines have null values. Because all rows have 9551 values . remaining Cuisines

# %% [markdown]
# Find the missing Values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Conclusion : Cuisines have 9 null values.

# %% [markdown]
# Describe the dataset

# %%
df.describe(include='all')
# Out:
#         Restaurant ID  Restaurant Name  Country Code       City  \
# count    9.551000e+03             9551   9551.000000       9551
# unique            NaN             7446           NaN        141
# top               NaN  Cafe Coffee Day           NaN  New Delhi
# freq              NaN               83           NaN       5473
# mean     9.051128e+06              NaN     18.365616        NaN
# std      8.791521e+06              NaN     56.750546        NaN
# min      5.300000e+01              NaN      1.000000        NaN
# 25%      3.019625e+05              NaN      1.000000        NaN
# 50%      6.004089e+06              NaN      1.000000        NaN
# 75%      1.835229e+07              NaN      1.000000        NaN
# max      1.850065e+07              NaN    216.000000        NaN
#
#                            Address         Locality  \
# count                         9551             9551
# unique                        8918             1208
# ...

# %%
# # Conclusion : 1.Here mean value is 25.85 and standard deviasion is 11.00 and minimum value is -41.33
# 2.Here (Q1)=25% value is 28.47 and (Q3) = 75% value is 28.64 and median value 50% is 28.57 and the maximum value is 55.97
# 3.Here the data is Symmetric data or Positive Data.

# %% [markdown]
# Find the duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Conclusion : There are 0 duplicate values in the data set

# %% [markdown]
# Last values of the data

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
# Conclusion : Here is the last 5 rows of the data set.

# %%
sns.scatterplot(df,x='Longitude',y='Currency')
# Out:
# <Axes: xlabel='Longitude', ylabel='Currency'>

# %%
# Conclusion : Botswana Pula(P) currency is very high remaining other value of currency . It Longitude approxmetly 147

# %%
df_country = pd.read_excel(r'D:\New folder\Country-Code.xlsx')

# %%
df_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
plt.pie(df_country['Country Code'][:6],labels=df_country['Country'][:6],autopct='%1.2f%%')
plt.show()

# %%
# Conclusion : Zomato maximum records in New Zealand and Indonesia and the least records in India it was 0.31%

# %%
sns.barplot(df,x='Votes',y='Rating text',hue='Rating color')
# Out:
# <Axes: xlabel='Votes', ylabel='Rating text'>

# %%
# Conclusion : Zomato rating is very high it is Excellent and zomato votes are also high it is approxmatly 1000 votes.

# %%
plt.figure(figsize=(10,8))
sns.countplot(df,x='Aggregate rating',palette=['green','red','yellow','orange'])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='count'>

# %%
# Conclusion : in 0.01 rating zomato aggregate rating is very high
# in 1.9 rating the aggregate rating is low

# %%
fig = plt.subplots(figsize=(17,6))
sns.boxplot(df,x='Price range', y='Aggregate rating')
# Out:
# <Axes: xlabel='Price range', ylabel='Aggregate rating'>

# %%
# Conclusion : In this box plot zomato price range going to high 
# in the first box there is no outliers.and aggregate rating is 2.8 and remaining all the values are equal aggregate rating

# %%
sns.countplot(df,x='Price range', palette= ['red', 'yellow', 'green', 'orange','blue'])
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %%
# Conclusion : Zomato price range 4300 it is very high price range and the lowest price range is 600.

# %%
df_zomato = df.select_dtypes(['float64', 'int64', 'object'])
df_zomato = df.drop('Country Code',axis=1)

# %%
sns.pairplot(df_zomato)

# %%
fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(10,5))
sns.histplot(df.Votes,kde=True,ax=axs[0])
sns.boxplot(df,x='Votes',ax=axs[1])
# Out:
# <Axes: xlabel='Votes'>

# %%
# Conclusion : in the histogram diagram votes have no outliers and the box plot the votes have outliers

# %%
sns.lmplot(df,x='Average Cost for two',y='Price range',ci=False)

# %%
# Conclusion : Zomato minimum price range is very high it has 5 above and after the line is outliers.

# %%
sns.violinplot(df,x='Country Code')
# Out:
# <Axes: xlabel='Country Code'>

# %%
# Conclusion : Zomato most delivered country is india and lowest delivered country is turkey.

# %%
df['Address'].value_counts().head().plot.bar(figsize=(13,6))
plt.title('Address Of the Restuarent')
# Out:
# Text(0.5, 1.0, 'Address Of the Restuarent')

# %%
# Conclusion : In New Delhi and noida Zomato Delivery are equal.lowest zomato delivery in gurgaon

# %%
zomato_corr = df[['Latitude', 'Country Code', 'Votes']]
sns.heatmap(zomato_corr.corr(),linewidth=1.0)
# Out:
# <Axes: >

# %%
# Conclusion : Here high correlation is 1.0 and lowest correlation is 0.0

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
# Conclusion : Here the correlation is 0.0 there is no correlation in this data.

# %%
sns.catplot(df,x='Rating text',y='Aggregate rating',hue='Has Table booking',palette='Oranges')
plt.show()

# %%
# Conclusion : zomato rating is excellent and low rating is not rated.

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Restaurant ID'}>,
#         <Axes: title={'center': 'Country Code'}>,
#         <Axes: title={'center': 'Longitude'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Average Cost for two'}>,
#         <Axes: title={'center': 'Price range'}>],
#        [<Axes: title={'center': 'Aggregate rating'}>,
#         <Axes: title={'center': 'Votes'}>, <Axes: >]], dtype=object)

# %%
# Conclusion : In the first plot restuarnt id is very high
# 2.the second plot Indonesia country is very low 
# 3.In the third plot Zomato longitutde is 8000.
# 4.In the third plot Zomato latitude is below 8000.
# 5.Zomato Average cost of two 9000.
# 6.In the next diagram zomato price range is going high.
# 7.next diagram zomato aggregate rating high at 2500 and lowest aggregate rating is 300 approx.
# 8.in the next one zomato voting is also high it is above of 10000 and the lowest votes is 0.
